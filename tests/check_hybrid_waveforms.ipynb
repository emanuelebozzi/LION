# %%
from obspy import read
import matplotlib.pyplot as plt

# Replace with the path to your file
filename = "/home/emanuele/data/emanuele/loki-das/cefalonia/orion_das_high_freq_complete_weak_less_subsection_also_non_selected_2_gilbert/kef0021/hybrid_gilbert/kef0021_hybrid_HHE_HHN.mseed"

# Read the miniSEED file into a Stream object
st = read(filename)

print(st)  # show summary of traces

# Plot all traces
st.plot(equal_scale=False, size=(800, 1600))

plt.show()
# Out:
# 28 Trace(s) in Stream:
#
# ST.ATHR..HHE | 2024-08-02T00:20:18.050000Z - 2024-08-02T00:20:38.050000Z | 100.0 Hz, 2001 samples
# ...
# (26 other traces)
# ...
# HY.363..HHE | 2024-08-02T00:20:18.049999Z - 2024-08-02T00:20:38.039999Z | 100.0 Hz, 2000 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
